# %%
#| hide
from generated_mne_for_eeg.core import *

# %% [markdown]
# # generated-mne-for-eeg
#
# > The Generated Guide to MNE for EEG

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install generated_mne_for_eeg in Development mode

# %% [markdown]
# ```sh
# # make sure generated_mne_for_eeg package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to generated_mne_for_eeg
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/bkowshik/generated-mne-for-eeg.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c bkowshik generated_mne_for_eeg
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install generated_mne_for_eeg
# ```
#
#
# [repo]: https://github.com/bkowshik/generated-mne-for-eeg
# [docs]: https://bkowshik.github.io/generated-mne-for-eeg/
# [pypi]: https://pypi.org/project/generated-mne-for-eeg/
# [conda]: https://anaconda.org/bkowshik/generated-mne-for-eeg

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/bkowshik/generated-mne-for-eeg
# [docs]: https://bkowshik.github.io/generated-mne-for-eeg/
# [pypi]: https://pypi.org/project/generated-mne-for-eeg/
# [conda]: https://anaconda.org/bkowshik/generated-mne-for-eeg

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
